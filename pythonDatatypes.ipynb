# %% [markdown]
# <a href="https://colab.research.google.com/github/SandhyaCodes09/DS-with-Python/blob/main/pythonDatatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#numerical
x=5

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
price = 26.25
print(price)
# Out:
# 26.25

# %%
num = 3e6
print(num)
# Out:
# 3000000.0

# %%
print(type(num))
# Out:
# <class 'float'>

# %%
z= 4+5j
print(type(z))
# Out:
# <class 'complex'>

# %%
# abs = absolute value /change negative no to positive
print(abs(-5))
# Out:
# 5

# %%
# power
print(pow(2,3))
# Out:
# 8

# %%
print(round(4.75))
print(round(4.5))
# Out:
# 5
# 4

# %%
nums = [3,3,5,4,7,1.9]
print(min(nums))
print(max(nums))
print(sum(nums))
# Out:
# 1.9
# 7
# 23.9

# %%
name = "Vishwa"
city = "Lucknow"
country = "India"

# %%
message = '''
Hello DSA in Python
'''

# %%
name = "Vishwa Mohan"
print(name[3])
# Out:
# h

# %%
 # print(name[12]) string out of range
print(name[-1])
print(name[-3])
# Out:
# n
# h

# %% [markdown]
# Concatenation

# %%
first_name = "Vishwa"
last_name = "Mohan"
full_name = first_name + " " + last_name
print(full_name)
# Out:
# Vishwa Mohan

# %% [markdown]
# length of string

# %%
print(len(full_name))
# Out:
# 12

# %%
str = "Saurabh Verma"
print(str[2:5])
# Out:
# ura

# %%
print(str[2:])
# Out:
# urabh Verma

# %%
print(str[: 4])
# Out:
# Saur

# %%
print(str[:])
# Out:
# Saurabh Verma

# %%
print(str[-9:-5])
# Out:
# abh

# %%
str = "  SaurabhManu"
print(str.upper())
print(str.lower())
print(str.capitalize())
print(str.strip())
# Out:
#   SAURABHMANU
#   saurabhmanu
#   saurabhmanu
# SaurabhManu

# %%
#replace method

str = "heelo Dear, I am very Good, I am very Nice, I am Wow"
print(str.replace("very","so",2))
# Out:
# heelo Dear, I am so Good, I am so Nice, I am Wow

# %%
#Escape character
print("Hello \n Saurabh")
# Out:
# Hello
#  Saurabh

# %%
print("Saurabh\tManu")
# Out:
# Saurabh	Manu

# %%
print("Komal \"Katiyar\"")
# Out:
# Komal "Katiyar"

# %% [markdown]
# Lerning List

# %%
students = ["Aashu", "Shreya", "Komal", "Suneel"]
print(students)
print(type(students))
# Out:
# ['Aashu', 'Shreya', 'Komal', 'Suneel']
# <class 'list'>

# %%
list2 = list(students)
print(list2)
print(type(list2))
# Out:
# ['Aashu', 'Shreya', 'Komal', 'Suneel']
# <class 'list'>

# %%
list3 = list("Varun Sharma")
print(list3)
# Out:
# ['V', 'a', 'r', 'u', 'n', ' ', 'S', 'h', 'a', 'r', 'm', 'a']

# %%
list4 = list((3,4,"Anshuu"))
print(list4)
# Out:
# [3, 4, 'Anshuu']

# %%
# Accessing the elements of the list

# %%
l1 = [1,3,5,7,8,10,15]
print(l1[3])
print(l1[6])
# Out:
# 7
# 15

# %%
arr = [3,1,4,7,9,8]
arr.append(11)
print(arr)
# Out:
# [3, 1, 4, 7, 9, 8, 11]

# %%
arr.insert(3,41)
print(arr)
# Out:
# [3, 1, 4, 41, 7, 9, 8, 11]

# %%
l1 = [1,3]
l2 =["Arun", "Manoj"]
l1.extend(l2)
print(l1)
# Out:
# [1, 3, 'Arun', 'Manoj']

# %%
# Remove elements from list

# %%
arr = [6,5,4,1,7, 9]
arr.remove(1)
print(arr)
# Out:
# [6, 5, 4, 7, 9]

# %%
arr = [3,2,5,1,7,9,1,8]
arr.remove(1)
print(arr)
# Out:
# [3, 2, 5, 7, 9, 1, 8]

# %%
print(arr.pop(3))
# Out:
# 7

# %%
std = ['a', 'b', 'c', 'd','e']
std[3] = 'f'
print(std)
# Out:
# ['a', 'b', 'c', 'f', 'e']

# %%
std[1:4] = 'n', 'm'
print(std)
# Out:
# ['a', 'n', 'm', 'e']

# %%
l1 = [1,2,3,4,5]
l1.reverse()
print(l1)
# Out:
# [5, 4, 3, 2, 1]

# %%
l1_copy = l1.copy()
print(l1_copy)
print(id(l1_copy), id(l1))
# Out:
# [5, 4, 3, 2, 1]
# 135563238216320 135563240560960

# %%
l1.sort()
print(l1)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Tuple

# %%
tup1 = (3,5,1,6,8,9)
print(tup1)
print(type(tup1))
# Out:
# (3, 5, 1, 6, 8, 9)
# <class 'tuple'>

# %%
tup1 = tuple([3,5,1,6])
print(tup1)
print(type(tup1))
# Out:
# (3, 5, 1, 6)
# <class 'tuple'>

# %%
t2 = tuple("Simran")
t3 = tuple(tup1)
print(t2,t3)
# Out:
# ('S', 'i', 'm', 'r', 'a', 'n') (3, 5, 1, 6)

# %%
fruits = ('apple','mango','banana','apple','mango','apple', 'strawberry')
print(fruits.count('apple'))
# Out:
# 3

# %%
print(fruits.index('mango'))
# Out:
# 1

# %%
print(len(fruits))
# Out:
# 7

# %%
print(fruits[3])
print(fruits[-3])
# Out:
# apple
# mango

# %%
#slicing

# %%
fruits = ('apple','mango','banana','apple','mango','apple', 'strawberry')

print(fruits[2:7])
# Out:
# ('banana', 'apple', 'mango', 'apple', 'strawberry')

# %% [markdown]
# Boolean

# %%
print(True)
print(False)
# Out:
# True
# False

# %% [markdown]
# Dictionary

# %%
print(students_details)
print(type(students_details))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5066/3119006247.py in <cell line: 0>()
# ----> 1 print(students_details)
#       2 print(type(students_details))
#
# NameError: name 'students_details' is not defined

# %%
dict1 = {1:"Sandhya", 2: "Verma", True : "cse" }
print(dict1)
# Out:
# {1: 'cse', 2: 'Verma'}

# %%
dict2 = { 3:"Sandhya", 2: "Lucknow"}
print(dict2)
# Out:
# {3: 'Sandhya', 2: 'Lucknow'}

# %%
# Dictionary constructor methods
dict1 = dict(name= "Sandhya", age ="24", True = "cse")
# Out:
#   File "/tmp/ipykernel_5066/1215324014.py", line 2
#     dict1 = dict(name= "Sandhya", age ="24", True = "cse")
#                                              ^
# SyntaxError: cannot assign to True

# %%
dict1 = dict(name= "Aashu", age = "18")
print(dict1)
print(type(dict1))
# Out:
# {'name': 'Aashu', 'age': '18'}
# <class 'dict'>

# %%
# access the elements of the dictionary
students_details = {'name': 'Saurabh', 'age': "24", 'city' : 'Lucknoow'}
print(students_details['name'])
print(students_details['age'])
# Out:
# Saurabh
# 24

# %%
print(students_details.keys())
print(students_details.values())
print(students_details.items())
# Out:
# dict_keys(['name', 'age', 'city'])
# dict_values(['Saurabh', '24', 'Lucknoow'])
# dict_items([('name', 'Saurabh'), ('age', '24'), ('city', 'Lucknoow')])

# %% [markdown]
# How do we add elelments in the dictionary | key,value

# %%
students_details = {'name': 'Annu', 'age': "25", 'city':'Noida'}
students_details['country'] = 'India'
print(students_details)
# Out:
# {'name': 'Annu', 'age': '25', 'city': 'Noida', 'country': 'India'}

# %%
students_details = {'name': 'Annu', 'age': "25", 'city':'Noida'}
marks_details = {'English' : 100, 'Maths': 80, 'Scirnce': 87}
students_details.update(marks_details)
print(students_details)
# Out:
# {'name': 'Annu', 'age': '25', 'city': 'Noida', 'English': 100, 'Maths': 80, 'Scirnce': 87}

# %%
# Remove the elements from the dictionary
print(students_details.pop('city'))
print(students_details)
# Out:
# Noida
# {'name': 'Annu', 'age': '25', 'English': 100, 'Maths': 80, 'Scirnce': 87}

# %%
print(students_details.popitem())
print(students_details)
# Out:
# ('Scirnce', 87)
# {'name': 'Annu', 'age': '25', 'English': 100, 'Maths': 80}

# %%
del students_details['age']
print(students_details)
# Out:
# {'name': 'Annu', 'English': 100, 'Maths': 80}

# %%
students_details.clear()
print(students_details)
# Out:
# {}

# %% [markdown]
# Set Datatypes

# %%
my_set = {1,2,3,4,5}
print(my_set)
print(type(my_set))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
s1 = {1,3,4,1,2,5,5,6,8}
print(s1)
# Out:
# {1, 2, 3, 4, 5, 6, 8}

# %%
set2 = set()
print(set2)
# Out:
# set()

# %%
s3 = ({6,15,9,17})
print(s3)
# Out:
# {9, 15, 17, 6}

# %%
#Add
s = set()

s.add(5)
s.add(14)
s.add(4)
s.add(7)
s.add(13)
print(s)
# Out:
# {4, 5, 7, 13, 14}

# %%
#Remove

s1 = {3,9,7,3}
print(s1.discard(7))
print(s1)
# Out:
# None
# {9, 3}

# %%
s1.remove(12)
print(s1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2378/926067076.py in <cell line: 0>()
# ----> 1 s1.remove(12)
#       2 print(s1)
#
# KeyError: 12

# %% [markdown]
# FrozenSet: Immutable Set

# %%
fs = frozenset({1,2,3})
print(fs)
print(type(fs))
# Out:
# frozenset({1, 2, 3})
# <class 'frozenset'>

# %%
fs2 = frozenset({3,5,7})
print(fs2)
# Out:
# frozenset({3, 5, 7})

# %%
dict1 = {fs2 : "Vishwa"}
print(dict1)
# Out:
# {frozenset({3, 5, 7}): 'Vishwa'}

# %%
# Implicit typecasting

x = 5
y = 7.4
result = x+y
print(result)
# Out:
# 12.4

# %%
y = '10'
print(type(y))
int_y = int(y)
print(type(int_y))
# Out:
# <class 'str'>
# <class 'int'>

# %%
str()
int()
float()
# Out:
# 0.0

# %%
data = 'one'
print(int(data))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2378/905666585.py in <cell line: 0>()
#       1 data = 'one'
# ----> 2 print(int(data))
#
# ValueError: invalid literal for int() with base 10: 'one'
